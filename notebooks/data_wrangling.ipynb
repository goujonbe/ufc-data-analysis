# %% [markdown]
# Exploratory analysis and data wrangling
# =======================================
#
# > Let's have a look at our dataset.
#
# > What we want to do:
# * have an general idea of the information the dataset contains
# * eliminate data we don't need
# * convert json files to csv files

# %%
import pandas as pd

# %%
# load the json file as a pandas dataframe
df_fighters = pd.read_json('../data/api/fighters.json')
# display the first two rows
df_fighters.head(2)
# Out:
#                                       belt_thumbnail  draws fighter_status  \
# 0  http://imagec.ufc.com/http%253A%252F%252Fmedia...    0.0         Active
# 1  http://imagec.ufc.com/http%253A%252F%252Fmedia...    0.0         Active
#
#   first_name      id last_name  \
# 0       Cris  241895    Cyborg
# 1      Nicco  644622   Montano
#
#                                 left_full_body_image  \
# 0  http://imagec.ufc.com/http%253A%252F%252Fmedia...
# 1  http://imagec.ufc.com/http%253A%252F%252Fmedia...
#
#                                        link  losses nickname  \
# 0    http://www.ufc.com/fighter/Cris-Cyborg     1.0     None
# 1  http://www.ufc.com/fighter/Nicco-Montano     2.0     None
#
#    pound_for_pound_rank                                      profile_image  \
# 0                  10.0  http://imagec.ufc.com/http%253A%252F%252Fmedia...
# 1                   NaN  http://imagec.ufc.com/http%253A%252F%252Fmedia...
#
#   rank                              right_full_body_image  statid  \
# 0    C  http://imagec.ufc.com/http%253A%252F%252Fmedia...  1194.0
# 1    C  http://imagec.ufc.com/http%253A%252F%252Fmedia...  3041.0
#
#                                            thumbnail  title_holder  \
# 0  http://imagec.ufc.com/http%253A%252F%252Fmedia...          True
# 1  http://imagec.ufc.com/http%253A%252F%252Fmedia...          True
#
#           weight_class  wins
# 0  Women_Featherweight  20.0
# 1      Women_Flyweight   5.0

# %%
# display essential information about the dataset such as the number of rows
# for each column
df_fighters.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 835 entries, 0 to 834
# Data columns (total 19 columns):
# belt_thumbnail           61 non-null object
# draws                    829 non-null float64
# fighter_status           835 non-null object
# first_name               835 non-null object
# id                       835 non-null int64
# last_name                835 non-null object
# left_full_body_image     750 non-null object
# link                     835 non-null object
# losses                   830 non-null float64
# nickname                 558 non-null object
# pound_for_pound_rank     15 non-null float64
# profile_image            835 non-null object
# rank                     178 non-null object
# right_full_body_image    752 non-null object
# statid                   758 non-null float64
# thumbnail                835 non-null object
# title_holder             835 non-null bool
# weight_class             829 non-null object
# wins                     830 non-null float64
# dtypes: bool(1), float64(5), int64(1), object(12)
# memory usage: 118.3+ KB

# %%
# create a new csv file with only the columns given
df_fighters.to_csv('../data/formated/fighters.csv', 
          index=False, 
          columns=['first_name',
                   'last_name',
                   'wins', 
                   'losses', 
                   'draws', 
                   'weight_class', 
                   'title_holder', 
                   'fighter_status'
                  ])

# %%
df_events = pd.read_json('../data/api/events.json')
df_events.head(2)
# Out:
#                   arena       base_title  corner_audio_available  \
# 0  Ibirapuera Gymnasium  UFC Fight Night                   False
# 1            Olimpiysky  UFC Fight Night                   False
#
#   corner_audio_blue_stream_url corner_audio_red_stream_url  \
# 0                         None                        None
# 1                         None                        None
#
#                 created     end_event_dategmt            event_date  \
# 0  2018-05-14T09:07:59Z  2018-09-23T05:00:00Z  2018-09-22T00:00:00Z
# 1  2018-05-16T08:27:02Z  2018-09-16T05:00:00Z  2018-09-15T00:00:00Z
#
#           event_dategmt event_status                 ...                  \
# 0  2018-09-22T23:00:00Z    ANNOUNCED                 ...
# 1  2018-09-15T23:00:00Z    ANNOUNCED                 ...
#
#                  subtitle ticket_general_sale_date ticket_general_sale_text  \
# 0             Live on FS1                     None           Public On-sale
# 1  Live on UFC FIGHT PASS     2018-06-01T10:00:00Z           Public On-sale
#
#   ticket_image  ticket_seller_name  \
# 0                             None
# 1                           Kassir
#
#                                            ticketurl title_tag_line  \
# 0                                                        TBA vs TBD
# 1  https://msk.kassir.ru/sport/olimpiyskiy/ufc-fi...     TBA vs TBD
#
#    trailer_url twitter_hashtag                            url_name
# 0         None                  fight-night-sao-paulo-sept-22-2018
# 1         None                     fight-night-moscow-sept-15-2018
#
# [2 rows x 35 columns]

# %%
df_events.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 497 entries, 0 to 496
# Data columns (total 35 columns):
# arena                           497 non-null object
# base_title                      497 non-null object
# corner_audio_available          497 non-null bool
# corner_audio_blue_stream_url    45 non-null object
# corner_audio_red_stream_url     45 non-null object
# created                         272 non-null object
# end_event_dategmt               497 non-null object
# event_date                      497 non-null object
# event_dategmt                   497 non-null object
# event_status                    497 non-null object
# event_time_text                 497 non-null object
# event_time_zone_text            497 non-null object
# feature_image                   497 non-null object
# fm_fnt_feed_url                 497 non-null object
# id                              497 non-null int64
# isppvevent                      497 non-null bool
# last_modified                   497 non-null object
# latitude                        97 non-null float64
# location                        497 non-null object
# longitude                       97 non-null float64
# main_event_fighter1_id          393 non-null float64
# main_event_fighter2_id          393 non-null float64
# secondary_feature_image         497 non-null object
# short_description               497 non-null object
# statid                          483 non-null float64
# subtitle                        497 non-null object
# ticket_general_sale_date        303 non-null object
# ticket_general_sale_text        497 non-null object
# ticket_image                    497 non-null object
# ticket_seller_name              182 non-null object
# ticketurl                       497 non-null object
# title_tag_line                  240 non-null object
# trailer_url                     82 non-null object
# twitter_hashtag                 497 non-null object
# url_name                        497 non-null object
# dtypes: bool(2), float64(5), int64(1), object(27)
# memory usage: 129.2+ KB
